# %% [markdown]
# # Forecasting - Coca Cola Data Set

# %%
import pandas as pd 
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt 
from pandas.plotting import lag_plot
import warnings
import statsmodels.formula.api as smf

# %%
coca=pd.read_excel("CocaCola_Sales_Rawdata.xlsx")
coca.head()
# Out:
#   Quarter        Sales
# 0   Q1_86  1734.827000
# 1   Q2_86  2244.960999
# 2   Q3_86  2533.804993
# 3   Q4_86  2154.962997
# 4   Q1_87  1547.818996

# %%
coca.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42 entries, 0 to 41
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Quarter  42 non-null     object
#  1   Sales    42 non-null     float64
# dtypes: float64(1), object(1)
# memory usage: 800.0+ bytes

# %% [markdown]
# ## Data Visualisation

# %%
from matplotlib import pyplot
coca.plot()
pyplot.show()

# %%
#histogram
coca.hist()
pyplot.show()

# %%
#density plot
coca=pd.read_excel("CocaCola_Sales_Rawdata.xlsx",header=0,index_col=0,parse_dates=True)
coca.plot(kind='kde')
pyplot.show()

# %%
#lag plot
lag_plot(coca)
pyplot.show()

# %%
#acf plot
from statsmodels.graphics.tsaplots import plot_acf
plot_acf(coca,lags=30)
pyplot.show()

# %% [markdown]
# ## Model Building

# %%
coca=pd.read_excel("CocaCola_Sales_Rawdata.xlsx")

# %%
coca['Quarters']= 0
coca['Year'] = 0
for i in range(42):
    p = coca["Quarter"][i]
    coca['Quarters'][i]= p[0:2]
    coca['Year'][i]= p[3:5]
coca.head()
# Out:
# C:\Users\Dell\AppData\Local\Temp/ipykernel_13608/1689538411.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   coca['Quarters'][i]= p[0:2]
# C:\Users\Dell\anaconda3\lib\site-packages\pandas\core\indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Dell\AppData\Local\Temp/ipykernel_13608/1689538411.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   coca['Year'][i]= p[3:5]
#   Quarter        Sales Quarters  Year
# 0   Q1_86  1734.827000       Q1    86
# 1   Q2_86  2244.960999       Q2    86
# 2   Q3_86  2533.804993       Q3    86
# 3   Q4_86  2154.962997       Q4    86
# 4   Q1_87  1547.818996       Q1    87

# %%
Q_dum=pd.DataFrame(pd.get_dummies(coca.Quarters))
Q_dum.head()
# Out:
#    Q1  Q2  Q3  Q4
# 0   1   0   0   0
# 1   0   1   0   0
# 2   0   0   1   0
# 3   0   0   0   1
# 4   1   0   0   0

# %%
coca=pd.concat([coca,Q_dum],axis=1)
coca.head()
# Out:
#   Quarter        Sales Quarters  Year  Q1  Q2  Q3  Q4
# 0   Q1_86  1734.827000       Q1    86   1   0   0   0
# 1   Q2_86  2244.960999       Q2    86   0   1   0   0
# 2   Q3_86  2533.804993       Q3    86   0   0   1   0
# 3   Q4_86  2154.962997       Q4    86   0   0   0   1
# 4   Q1_87  1547.818996       Q1    87   1   0   0   0

# %%
coca['t']=range(1,43)
coca.head()
# Out:
#   Quarter        Sales Quarters  Year  Q1  Q2  Q3  Q4  t
# 0   Q1_86  1734.827000       Q1    86   1   0   0   0  1
# 1   Q2_86  2244.960999       Q2    86   0   1   0   0  2
# 2   Q3_86  2533.804993       Q3    86   0   0   1   0  3
# 3   Q4_86  2154.962997       Q4    86   0   0   0   1  4
# 4   Q1_87  1547.818996       Q1    87   1   0   0   0  5

# %%
coca['t_squared']=coca.t*coca.t
coca.head()
# Out:
#   Quarter        Sales Quarters  Year  Q1  Q2  Q3  Q4  t  t_squared
# 0   Q1_86  1734.827000       Q1    86   1   0   0   0  1          1
# 1   Q2_86  2244.960999       Q2    86   0   1   0   0  2          4
# 2   Q3_86  2533.804993       Q3    86   0   0   1   0  3          9
# 3   Q4_86  2154.962997       Q4    86   0   0   0   1  4         16
# 4   Q1_87  1547.818996       Q1    87   1   0   0   0  5         25

# %%
coca['log_Sales']=np.log(coca.Sales)
coca.head()
# Out:
#   Quarter        Sales Quarters  Year  Q1  Q2  Q3  Q4  t  t_squared  log_Sales
# 0   Q1_86  1734.827000       Q1    86   1   0   0   0  1          1   7.458663
# 1   Q2_86  2244.960999       Q2    86   0   1   0   0  2          4   7.716443
# 2   Q3_86  2533.804993       Q3    86   0   0   1   0  3          9   7.837477
# 3   Q4_86  2154.962997       Q4    86   0   0   0   1  4         16   7.675529
# 4   Q1_87  1547.818996       Q1    87   1   0   0   0  5         25   7.344602

# %%
plt.figure(figsize=(12,10))
plot_month_y=pd.pivot_table(data=coca,values='Sales',index='Year',columns='Quarters',aggfunc='mean',fill_value=0)
sns.heatmap(plot_month_y,annot=True,fmt='g')
# Out:
# <AxesSubplot:xlabel='Quarters', ylabel='Year'>

# %%
# Boxplot 
plt.figure(figsize=(8,6))
plt.subplot(211)
sns.boxplot(x="Quarters",y="Sales",data=coca)
plt.subplot(212)
sns.boxplot(x="Year",y="Sales",data=coca)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Sales'>

# %%
sns.lineplot(x='Year',y='Sales',data=coca)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Sales'>

# %%
#Splitting the data 
train=coca.head(35)
test=coca.tail(7)

# %% [markdown]
# ### Linear Model

# %%
linear_model = smf.ols('Sales~t',data=train).fit()
pred_linear =  pd.Series(linear_model.predict(pd.DataFrame(test['t'])))
rmse_linear = np.sqrt(np.mean((np.array(test['Sales'])-np.array(pred_linear))**2))
rmse_linear
# Out:
# 636.5072930351146

# %% [markdown]
# ### Exponential Model

# %%
exp_model = smf.ols('log_Sales~t',data=train).fit()
pred_exp = pd.Series(exp_model.predict(pd.DataFrame(test['t'])))
rmse_exp = np.sqrt(np.mean((np.array(test['Sales'])-np.array(np.exp(pred_exp)))**2))
rmse_exp
# Out:
# 493.348648484222

# %% [markdown]
# ### Quadratic Model

# %%
quad_model = smf.ols('Sales~t+t_squared',data=train).fit()
pred_quad = pd.Series(quad_model.predict(test[["t","t_squared"]]))
rmse_quad = np.sqrt(np.mean((np.array(test['Sales'])-np.array(pred_quad))**2))
rmse_quad
# Out:
# 511.81173194173283

# %% [markdown]
# ### Additive Seasonality Model

# %%
add_sea_model = smf.ols('Sales~Q1+Q2+Q3+Q4',data=train).fit()
pred_add_sea = pd.Series(add_sea_model.predict(test[['Q1','Q2','Q3','Q4']]))
rmse_add_sea = np.sqrt(np.mean((np.array(test['Sales'])-np.array(pred_add_sea))**2))
rmse_add_sea
# Out:
# 1861.870416425175

# %% [markdown]
# ### Additive Seasonality Quadratic Model

# %%
add_sea_Quad_model = smf.ols('Sales~t+t_squared+Q1+Q2+Q3+Q4',data=train).fit()
pred_add_sea_quad = pd.Series(add_sea_Quad_model.predict(test[['t','t_squared','Q1','Q2','Q3','Q4']]))
rmse_add_sea_quad = np.sqrt(np.mean((np.array(test['Sales'])-np.array(pred_add_sea_quad))**2))
rmse_add_sea_quad
# Out:
# 309.4641395163693

# %% [markdown]
# ### Multiplicative Seasonality Model

# %%
mul_sea_model = smf.ols('log_Sales~Q1+Q2+Q3+Q4',data = train).fit()
pred_mult_sea = pd.Series(mul_sea_model.predict(test))
rmse_mult_sea = np.sqrt(np.mean((np.array(test['Sales'])-np.array(np.exp(pred_mult_sea)))**2))
rmse_mult_sea
# Out:
# 1938.9332351966193

# %% [markdown]
# ### Multiplicative Seasonality Quadratic Model

# %%
mul_sea_Quad_model = smf.ols('log_Sales~t+t_squared+Q1+Q2+Q3+Q4',data=train).fit()
pred_mul_sea_quad = pd.Series(mul_sea_Quad_model.predict(test[['t','t_squared','Q1','Q2','Q3','Q4']]))
rmse_mul_sea_quad = np.sqrt(np.mean((np.array(test['Sales'])-np.array(pred_mul_sea_quad))**2))
rmse_mul_sea_quad
# Out:
# 4515.62473844014

# %% [markdown]
# ### Multiplicative Additive Seasonality

# %%
mul_add_sea = smf.ols('log_Sales~t+Q1+Q2+Q3+Q4',data = train).fit()
pred_mult_add_sea = pd.Series(mul_add_sea.predict(test))
rmse_mult_add_sea = np.sqrt(np.mean((np.array(test['Sales'])-np.array(np.exp(pred_mult_add_sea)))**2))
rmse_mult_add_sea
# Out:
# 339.1874666994836

# %% [markdown]
# ### Comparing results

# %%
data1 = {"MODEL":pd.Series(["rmse_linear","rmse_Exp","rmse_Quad","rmse_add_sea","rmse_add_sea_quad","rmse_Mult_sea","rmse_Mult_add_sea","rmse_Mult_sea_quad"]),"RMSE_Values":pd.Series([rmse_linear,rmse_exp,rmse_quad,rmse_add_sea,rmse_add_sea_quad,rmse_mult_sea,rmse_mult_add_sea,rmse_mul_sea_quad])}
table_rmse=pd.DataFrame(data1)
table_rmse.sort_values(['RMSE_Values'])
# Out:
#                 MODEL  RMSE_Values
# 4   rmse_add_sea_quad   309.464140
# 6   rmse_Mult_add_sea   339.187467
# 1            rmse_Exp   493.348648
# 2           rmse_Quad   511.811732
# 0         rmse_linear   636.507293
# 3        rmse_add_sea  1861.870416
# 5       rmse_Mult_sea  1938.933235
# 7  rmse_Mult_sea_quad  4515.624738

# %% [markdown]
# ### Predict for new time period

# %%
pred_data=coca
pred_data.head()
# Out:
#   Quarter        Sales Quarters  Year  Q1  Q2  Q3  Q4  t  t_squared  log_Sales
# 0   Q1_86  1734.827000       Q1    86   1   0   0   0  1          1   7.458663
# 1   Q2_86  2244.960999       Q2    86   0   1   0   0  2          4   7.716443
# 2   Q3_86  2533.804993       Q3    86   0   0   1   0  3          9   7.837477
# 3   Q4_86  2154.962997       Q4    86   0   0   0   1  4         16   7.675529
# 4   Q1_87  1547.818996       Q1    87   1   0   0   0  5         25   7.344602

# %%
#build the model on entire dataset
model_full=smf.ols('Sales~t+t_squared+Q1+Q2+Q3+Q4',data=coca).fit()

# %% [markdown]
# ### RMSE shows the original error. In this case Additive Seasonality Quadratic model shows the least error. Hence we'll use its rmse value to forecast the model.

# %%
pred_new=pd.Series(add_sea_Quad_model.predict(pred_data))
pred_new
# Out:
# 0     1715.011163
# 1     2277.750192
# 2     2194.873446
# 3     1919.651866
# 4     1703.261332
# 5     2283.439187
# 6     2218.001266
# 7     1960.218512
# 8     1761.266805
# 9     2358.883485
# 10    2310.884390
# 11    2070.540461
# 12    1889.027579
# 13    2504.083086
# 14    2473.522816
# 15    2250.617713
# 16    2086.543657
# 17    2719.037989
# 18    2705.916545
# 19    2500.450268
# 20    2353.815037
# 21    3003.748194
# 22    3008.065576
# 23    2820.038125
# 24    2690.841720
# 25    3358.213703
# 26    3379.969910
# 27    3209.381284
# 28    3097.623705
# 29    3782.434514
# 30    3821.629547
# 31    3668.479747
# 32    3574.160993
# 33    4276.410627
# 34    4333.044486
# 35    4197.333511
# 36    4120.453583
# 37    4840.142044
# 38    4914.214728
# 39    4795.942579
# 40    4736.501477
# 41    5473.628762
# dtype: float64

# %%
pred_data['forecated_sales']=pd.Series(pred_new)
pred_data
# Out:
#    Quarter        Sales Quarters  Year  Q1  Q2  Q3  Q4   t  t_squared  \
# 0    Q1_86  1734.827000       Q1    86   1   0   0   0   1          1
# 1    Q2_86  2244.960999       Q2    86   0   1   0   0   2          4
# 2    Q3_86  2533.804993       Q3    86   0   0   1   0   3          9
# 3    Q4_86  2154.962997       Q4    86   0   0   0   1   4         16
# 4    Q1_87  1547.818996       Q1    87   1   0   0   0   5         25
# 5    Q2_87  2104.411995       Q2    87   0   1   0   0   6         36
# 6    Q3_87  2014.362999       Q3    87   0   0   1   0   7         49
# 7    Q4_87  1991.746998       Q4    87   0   0   0   1   8         64
# 8    Q1_88  1869.049999       Q1    88   1   0   0   0   9         81
# 9    Q2_88  2313.631996       Q2    88   0   1   0   0  10        100
# 10   Q3_88  2128.320000       Q3    88   0   0   1   0  11        121
# 11   Q4_88  2026.828999       Q4    88   0   0   0   1  12        144
# 12   Q1_89  1910.603996       Q1    89   1   0   0   0  13        169
# 13   Q2_89  2331.164993       Q2    89   0   1   0   0  14        196
# 14   Q3_89  2206.549995       Q3    89   0   0   1   0  15        225
# 15   Q4_89  2173.967995       Q4    89   0   0   0   1  16        256
# 16   Q1_90  2148.278000       Q1    90   1   0   0   0  17        289
# 17   Q2_90  2739.307999       Q2    90   0   1   0   0  18        324
# 18   Q3_90  2792.753998       Q3    90   0   0   1   0  19        361
# 19   Q4_90  2556.009995       Q4    90   0   0   0   1  20        400
# 20   Q1_91  2480.973999       Q1    91   1   0   0   0  21        441
# 21   Q2_91  3039.522995       Q2    91   0   1   0   0  22        484
# 22   Q3_91  3172.115997       Q3    91   0   0   1   0  23        529
# 23   Q4_91  2879.000999       Q4    91   0   0   0   1  24        576
# 24   Q1_92  2772.000000       Q1    92   1   0   0   0  25        625
# 25   Q2_92  3550.000000       Q2    92   0   1   0   0  26        676
# 26   Q3_92  3508.000000       Q3    92   0   0   1   0  27        729
# 27   Q4_92  3243.859993       Q4    92   0   0   0   1  28        784
# 28   Q1_93  3056.000000       Q1    93   1   0   0   0  29        841
# 29   Q2_93  3899.000000       Q2    93   0   1   0   0  30        900
# 30   Q3_93  3629.000000       Q3    93   0   0   1   0  31        961
# 31   Q4_93  3373.000000       Q4    93   0   0   0   1  32       1024
# 32   Q1_94  3352.000000       Q1    94   1   0   0   0  33       1089
# 33   Q2_94  4342.000000       Q2    94   0   1   0   0  34       1156
# 34   Q3_94  4461.000000       Q3    94   0   0   1   0  35       1225
# 35   Q4_94  4017.000000       Q4    94   0   0   0   1  36       1296
# 36   Q1_95  3854.000000       Q1    95   1   0   0   0  37       1369
# 37   Q2_95  4936.000000       Q2    95   0   1   0   0  38       1444
# 38   Q3_95  4895.000000       Q3    95   0   0   1   0  39       1521
# 39   Q4_95  4333.000000       Q4    95   0   0   0   1  40       1600
# 40   Q1_96  4194.000000       Q1    96   1   0   0   0  41       1681
# 41   Q2_96  5253.000000       Q2    96   0   1   0   0  42       1764
#
#     log_Sales  forecated_sales
# 0    7.458663      1715.011163
# 1    7.716443      2277.750192
# 2    7.837477      2194.873446
# 3    7.675529      1919.651866
# 4    7.344602      1703.261332
# 5    7.651791      2283.439187
# 6    7.608058      2218.001266
# 7    7.596767      1960.218512
# 8    7.533186      1761.266805
# 9    7.746574      2358.883485
# 10   7.663088      2310.884390
# 11   7.614228      2070.540461
# 12   7.555175      1889.027579
# 13   7.754123      2504.083086
# 14   7.699185      2473.522816
# 15   7.684309      2250.617713
# 16   7.672422      2086.543657
# 17   7.915461      2719.037989
# 18   7.934783      2705.916545
# 19   7.846203      2500.450268
# 20   7.816407      2353.815037
# 21   8.019456      3003.748194
# 22   8.062154      3008.065576
# 23   7.965199      2820.038125
# 24   7.927324      2690.841720
# 25   8.174703      3358.213703
# 26   8.162801      3379.969910
# 27   8.084519      3209.381284
# 28   8.024862      3097.623705
# 29   8.268475      3782.434514
# 30   8.196712      3821.629547
# 31   8.123558      3668.479747
# 32   8.117312      3574.160993
# 33   8.376090      4276.410627
# 34   8.403128      4333.044486
# 35   8.298291      4197.333511
# 36   8.256867      4120.453583
# 37   8.504311      4840.142044
# 38   8.495970      4914.214728
# 39   8.374015      4795.942579
# 40   8.341410      4736.501477
# 41   8.566555      5473.628762
